# %% [markdown]
# # UCC Applied Data Literacy: guided Colab activity
#
# **Illustrative facilitator template.** Complete every task marked **LEARNER TASK**, preserve the evidence trail, and export the finished notebook as `.ipynb`.
#
# Learning outcomes: inspect data quality (LO1), perform reproducible analysis (LO2), communicate a finding and limitation (LO3), and document ethical handling (LO4).

# %% [markdown]
# ## 1. Decision question and data dictionary
# Which learner-support channel should receive additional attention next month? The demonstration data are fictional and contain deliberate quality problems.

# %%
import pandas as pd
import matplotlib.pyplot as plt

records = [
    {'case_id':'A01','channel':'Email','resolution_minutes':42,'satisfaction':4},
    {'case_id':'A02','channel':'Chat','resolution_minutes':18,'satisfaction':5},
    {'case_id':'A03','channel':'email ','resolution_minutes':55,'satisfaction':3},
    {'case_id':'A04','channel':'Phone','resolution_minutes':None,'satisfaction':2},
    {'case_id':'A04','channel':'Phone','resolution_minutes':71,'satisfaction':2},
    {'case_id':'A05','channel':'Chat','resolution_minutes':15,'satisfaction':5},
]
raw = pd.DataFrame(records)
raw

# %% [markdown]
# ### LEARNER TASK 1 — inspect before cleaning
# Identify the unit of analysis, missing values, duplicate identifiers, inconsistent categories and any ethical limitation. Record your observations below.

# %%
# Write inspection code here. Keep the raw dataframe unchanged.
raw.info()
raw.isna().sum()

# %% [markdown]
# **Inspection notes:** Replace this sentence with your observations and the reason each issue matters.

# %% [markdown]
# ### LEARNER TASK 2 — create a documented cleaning trail
# Copy the raw data, standardise categories, resolve the duplicate using a stated rule and handle the missing value without hiding it.

# %%
clean = raw.copy()
# TODO: add documented cleaning steps
clean

# %% [markdown]
# ### LEARNER TASK 3 — calculate and visualise
# Calculate case count, median resolution time and mean satisfaction by channel. Create one accessible chart with a decision-focused title, labelled axes, units and source note.

# %%
# TODO: produce a summary table
summary = None
summary

# %%
# TODO: create an accessible chart
# Add a concise text description of the chart in the next cell.

# %% [markdown]
# ### LEARNER TASK 4 — communicate responsibly
# Write: (1) one observed finding; (2) one limitation; (3) one proportionate recommendation; and (4) the next evidence needed before a high-stakes decision.
#
# **Finding:**
# **Limitation:**
# **Recommendation:**
# **Next evidence:**

# %% [markdown]
# ## Submission check
# - Restart and run all cells successfully.
# - Keep the raw data and cleaning trail visible.
# - Confirm the chart is readable without relying on colour alone.
# - Download the completed notebook: **File → Download → Download .ipynb**.
# - Submit the notebook or an authorised sharing link in the learner portal.
